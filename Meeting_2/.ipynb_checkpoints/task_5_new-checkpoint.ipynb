# %% [markdown]
# Task 7

# %%
def read_signed_graph_from_file(file_path):
    graph = {}
    with open(file_path, 'r') as file:
        for line in file:
            source, target, weight = map(int, line.strip().split())
            if source not in graph:
                graph[source] = []
            if target not in graph:
                graph[target] = []
            graph[source].append((target, weight))
            graph[target].append((source, weight))
    return graph

# %%
file_path = r"/Users/mac/Desktop/Desktop/RCS_Signed_Graph/Meeting_2/graph_check/ads_graph_check1.txt"
graph = read_signed_graph_from_file(file_path)

print(graph)
# Out:
# {1: [(2, -1), (6, -1)], 2: [(1, -1), (3, 1), (5, -1)], 6: [(1, -1), (4, -1)], 3: [(2, 1), (4, -1), (5, -1)], 5: [(2, -1), (3, -1)], 4: [(3, -1), (6, -1)]}

# %%
def check_condition2(s, sbar, pos_count = 0):
    is_check = False
    for s_node in s:
#         print("checking conditon 2 for s node", s_node)
        if s_node not in asd:
            neg_count = 0
            for sbar_node in sbar:
                for nei, sign in graph[sbar_node]:
                    if nei == s_node:
                        if sign == -1:
                            neg_count += 1
            if pos_count + 1 >= neg_count:
#                 print("condition 2 statisfied")
                is_check = True
    
    if is_check:
        asd.append(s) 
            
def check_condition1(s):
    is_statisfied = False
    for vertex1 in s:
#         print("checking conditon 1 for vertex" , vertex1)
        pos_count = 0
        neg_count = 0
        for nei, sign in graph[vertex1]:
            for vertex2 in s:
                if nei == vertex2:
                    if sign == 1:
                        pos_count += 1
                    else:
                        neg_count += 1
        if pos_count + 1 >= neg_count:
#             print("condition 1 statisfied")
            is_statisfied =  True
        else:
            is_statisfied =  False
    return is_statisfied, pos_count

# %%
from itertools import combinations
a = [1, 2, 3, 4, 5, 6]
asd = list()
# Generate all 6 combinations
for i in range(1, len(a)):
    if not asd:
        s = list(combinations(a, i))
        for combo in s:
            s = combo 
            sbar = [x for x in nodes if x not in s]
            print(s,sbar)
            if len(s) > 1:
#                 print("combination length greater 1")
                is_checked, pos_count = check_condition1(s)
                if is_checked:
                    check_condition2(s, sbar, pos_count)
            else:
                check_condition2(s,sbar) 
    else:
        print(asd)
        break
# Out:
# (1,) [2, 3, 4, 5, 6]
# checking conditon 2 for s node 1
# (2,) [1, 3, 4, 5, 6]
# checking conditon 2 for s node 2
# (3,) [1, 2, 4, 5, 6]
# checking conditon 2 for s node 3
# (4,) [1, 2, 3, 5, 6]
# checking conditon 2 for s node 4
# (5,) [1, 2, 3, 4, 6]
# checking conditon 2 for s node 5
# (6,) [1, 2, 3, 4, 5]
# checking conditon 2 for s node 6
# (1, 2) [3, 4, 5, 6]
# combination length greater 1
# checking conditon 1 for vertex 1
# condition 1 statisfied
# checking conditon 1 for vertex 2
# condition 1 statisfied
# checking conditon 2 for s node 1
# condition 2 statisfied
# checking conditon 2 for s node 2
# condition 2 statisfied
# (1, 3) [2, 4, 5, 6]
# combination length greater 1
# checking conditon 1 for vertex 1
# condition 1 statisfied
# checking conditon 1 for vertex 3
# condition 1 statisfied
# checking conditon 2 for s node 1
# checking conditon 2 for s node 3
# (1, 4) [2, 3, 5, 6]
# combination length greater 1
# checking conditon 1 for vertex 1
# condition 1 statisfied
# checking conditon 1 for vertex 4
# condition 1 statisfied
# checking conditon 2 for s node 1
# checking conditon 2 for s node 4
# (1, 5) [2, 3, 4, 6]
# combination length greater 1
# checking conditon 1 for vertex 1
# condition 1 statisfied
# checking conditon 1 for vertex 5
# condition 1 statisfied
# checking conditon 2 for s node 1
# checking conditon 2 for s node 5
# (1, 6) [2, 3, 4, 5]
# combination length greater 1
# checking conditon 1 for vertex 1
# condition 1 statisfied
# checking conditon 1 for vertex 6
# condition 1 statisfied
# checking conditon 2 for s node 1
# condition 2 statisfied
# checking conditon 2 for s node 6
# condition 2 statisfied
# (2, 3) [1, 4, 5, 6]
# combination length greater 1
# checking conditon 1 for vertex 2
# condition 1 statisfied
# checking conditon 1 for vertex 3
# condition 1 statisfied
# checking conditon 2 for s node 2
# condition 2 statisfied
# checking conditon 2 for s node 3
# condition 2 statisfied
# (2, 4) [1, 3, 5, 6]
# combination length greater 1
# checking conditon 1 for vertex 2
# condition 1 statisfied
# checking conditon 1 for vertex 4
# condition 1 statisfied
# checking conditon 2 for s node 2
# checking conditon 2 for s node 4
# (2, 5) [1, 3, 4, 6]
# combination length greater 1
# checking conditon 1 for vertex 2
# condition 1 statisfied
# checking conditon 1 for vertex 5
# condition 1 statisfied
# checking conditon 2 for s node 2
# condition 2 statisfied
# checking conditon 2 for s node 5
# condition 2 statisfied
# (2, 6) [1, 3, 4, 5]
# combination length greater 1
# checking conditon 1 for vertex 2
# condition 1 statisfied
# checking conditon 1 for vertex 6
# condition 1 statisfied
# checking conditon 2 for s node 2
# checking conditon 2 for s node 6
# (3, 4) [1, 2, 5, 6]
# combination length greater 1
# checking conditon 1 for vertex 3
# condition 1 statisfied
# checking conditon 1 for vertex 4
# condition 1 statisfied
# checking conditon 2 for s node 3
# condition 2 statisfied
# checking conditon 2 for s node 4
# condition 2 statisfied
# (3, 5) [1, 2, 4, 6]
# combination length greater 1
# checking conditon 1 for vertex 3
# condition 1 statisfied
# checking conditon 1 for vertex 5
# condition 1 statisfied
# checking conditon 2 for s node 3
# condition 2 statisfied
# checking conditon 2 for s node 5
# condition 2 statisfied
# (3, 6) [1, 2, 4, 5]
# combination length greater 1
# checking conditon 1 for vertex 3
# condition 1 statisfied
# checking conditon 1 for vertex 6
# condition 1 statisfied
# checking conditon 2 for s node 3
# checking conditon 2 for s node 6
# (4, 5) [1, 2, 3, 6]
# combination length greater 1
# checking conditon 1 for vertex 4
# condition 1 statisfied
# checking conditon 1 for vertex 5
# condition 1 statisfied
# checking conditon 2 for s node 4
# checking conditon 2 for s node 5
# (4, 6) [1, 2, 3, 5]
# combination length greater 1
# checking conditon 1 for vertex 4
# condition 1 statisfied
# checking conditon 1 for vertex 6
# condition 1 statisfied
# checking conditon 2 for s node 4
# condition 2 statisfied
# checking conditon 2 for s node 6
# condition 2 statisfied
# (5, 6) [1, 2, 3, 4]
# combination length greater 1
# checking conditon 1 for vertex 5
# condition 1 statisfied
# checking conditon 1 for vertex 6
# condition 1 statisfied
# checking conditon 2 for s node 5
# checking conditon 2 for s node 6
# [(1, 2), (1, 6), (2, 3), (2, 5), (3, 4), (3, 5), (4, 6)]
